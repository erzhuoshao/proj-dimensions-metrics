# %%
import pandas as pd, numpy as np
from matplotlib import pyplot as plt
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 50)

import json, pickle as pkl
from unidecode import unidecode
from glob import glob
from collections import Counter, defaultdict
from itertools import product, combinations
from copy import deepcopy

from functools import partial
from tqdm import tqdm, trange
tqdm.pandas(ncols=100, mininterval=1)
tqdm, trange = partial(tqdm, ncols=100, mininterval=1), partial(trange, ncols=100, mininterval=1)
import pandas as pd
import os, shutil

# %%
# %%time
paper_patents = pd.read_parquet("../parquet/processed/paper_patents.parquet")
paper_patents["id"] = paper_patents["id"].map(lambda x: int(x[4:]))
# Out:
# CPU times: user 19.2 s, sys: 2.28 s, total: 21.5 s
# Wall time: 18.9 s

# %%
# %time dict_citing_to_cited = dict_citing_to_cited.set_index("citing_paperid").cited_list.to_dict()
# Out:
# CPU times: user 1min 20s, sys: 16.9 s, total: 1min 37s
# Wall time: 1min 37s

# %%
# %%time

known_paper_dict = set(paper_patents.id.unique().tolist())

distance_to_paper_dict = [set(paper_patents.id.unique().tolist())]

for distance in trange(10000):
    distance_to_paper_dict.append([])
    for citing in distance_to_paper_dict[-2]:
        cited_list = [i[0] for i in dict_citing_to_cited.get(citing, [])]
        distance_to_paper_dict[-1] += cited_list
    distance_to_paper_dict[-1], known_paper_dict = set(distance_to_paper_dict[-1]) - known_paper_dict, set(distance_to_paper_dict[-1]) | known_paper_dict
    print(f'Distance = {distance + 2}\t\t# Paper =', len(distance_to_paper_dict[-1]))
    if len(distance_to_paper_dict[-1]) == 0:
        break
# Out:
#   0%|                                                        | 1/10000 [01:59<331:55:29, 119.50s/it]
# Distance = 2		# Paper = 18500590
#   0%|                                                        | 2/10000 [09:38<887:13:54, 319.47s/it]
# Distance = 3		# Paper = 18237356
#   0%|                                                        | 3/10000 [16:15<984:56:03, 354.68s/it]
# Distance = 4		# Paper = 9773323
#   0%|                                                        | 4/10000 [19:31<811:03:34, 292.10s/it]
# Distance = 5		# Paper = 4579080
#   0%|                                                        | 5/10000 [20:54<601:34:45, 216.68s/it]
# Distance = 6		# Paper = 2155390
#   0%|                                                        | 6/10000 [21:41<441:13:42, 158.94s/it]
# Distance = 7		# Paper = 1061638
#   0%|                                                        | 7/10000 [22:13<326:15:07, 117.53s/it]
# Distance = 8		# Paper = 548265
# ...

# %%
paper_patent_distance_df = []

for i in trange(len(distance_to_paper_dict) - 1):
    distance = i + 1
    papers = distance_to_paper_dict[distance]
    for paper in papers:
        paper_patent_distance_df.append([paper, distance])
# Out:
# 100%|███████████████████████████████████████████████████████████████| 40/40 [10:04<00:00, 15.11s/it]

# %%
paper_patent_distance_df = pd.DataFrame(paper_patent_distance_df, columns=['paper_id', 'distance'])
paper_patent_distance_df.to_csv('data/paper_patent_distance.tsv', index=False, sep='\t')
paper_patent_distance_df.to_feather('data/paper_patent_distance.feather')
